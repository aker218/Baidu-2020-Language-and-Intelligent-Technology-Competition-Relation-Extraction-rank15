# %%
import json
pred_data_1=[]
pred_num_1=0
with open("./predict_res kg.json","r") as r:
    raw_data=r.readlines()
    for d in raw_data:
        pred_data_1.append(json.loads(d))
        pred_num_1+=len(pred_data_1[-1]['spo_list'])
pred_num_1
# Out:
# 24679

# %%
import unicodedata
def _is_whitespace(char):
    """Checks whether `chars` is a whitespace character."""
    # \t, \n, and \r are technically contorl characters but we treat them
    # as whitespace since they are generally considered as such.
    if char == " " or char == "\t" or char == "\n" or char == "\r":
        return True
    cat = unicodedata.category(char)
    if cat == "Zs":
        return True
    return False
def is_chinese_char(cp):
    """Checks whether CP is the codepoint of a CJK character."""
    # This defines a "chinese character" as anything in the CJK Unicode block:
    #   https://en.wikipedia.org/wiki/CJK_Unified_Ideographs_(Unicode_block)
    #
    # Note that the CJK Unicode block is NOT all Japanese and Korean characters,
    # despite its name. The modern Korean Hangul alphabet is a different block,
    # as is Japanese Hiragana and Katakana. Those alphabets are used to write
    # space-separated words, so they are not treated specially and handled
    # like the all of the other languages.
    if (
        (cp >= 0x4E00 and cp <= 0x9FFF)
        or (cp >= 0x3400 and cp <= 0x4DBF)  #
        or (cp >= 0x20000 and cp <= 0x2A6DF)  #
        or (cp >= 0x2A700 and cp <= 0x2B73F)  #
        or (cp >= 0x2B740 and cp <= 0x2B81F)  #
        or (cp >= 0x2B820 and cp <= 0x2CEAF)  #
        or (cp >= 0xF900 and cp <= 0xFAFF)
        or (cp >= 0x2F800 and cp <= 0x2FA1F)  #
    ):  #
        return True

    return False
def is_punctuation(char):
    """Checks whether `chars` is a punctuation character."""
    cp = ord(char)
    # We treat all non-letter/number ASCII as punctuation.
    # Characters such as "^", "$", and "`" are not in the Unicode
    # Punctuation class but we treat them as punctuation anyways, for
    # consistency.
    if (cp >= 33 and cp <= 47) or (cp >= 58 and cp <= 64) or (cp >= 91 and cp <= 96) or (cp >= 123 and cp <= 126):
        return True
    cat = unicodedata.category(char)
    if cat.startswith("P"):
        return True
    return False

# %%
for idx,e in enumerate(pred_data_1):
    for spo in e['spo_list']:
        while spo['subject'][0]=='《' and ( spo['subject'][-1]=='》' or  spo['subject'].find("》")==-1):
            print("sub",spo['subject'])
            spo['subject']=spo['subject'].replace("《","").replace("》","")
            print("sub",spo['subject'])         
            break
        poped_keys=[]
        for key,value in spo['object'].items():
            if len(value)==0:
                print(spo)
                poped_keys.append(key)
            if len(poped_keys)>0:
                for t in poped_keys:
                    print(t)
                    spo['object'].pop(t)
                    spo['object_type'].pop(t)
                print(idx,pred_data_1[idx])
                break
            while value[0]=='《' and (value[-1]=='》' or value.find("》")==-1):
                print("ob",key,value)
                spo['object'][key]=value.replace("《","").replace("》","")
                print("ob",spo['object'][key])        
                break

# %%
with open("./predict_res kg.json","w") as w:
    for e in pred_data_1:
        w.write(json.dumps(e, ensure_ascii=False)+'\n')

# %%
pred_data_2=[]
pred_num_2=0
with open("./test1_res.json","r") as r:
    raw_data=r.readlines()
    for d in raw_data:
        pred_data_2.append(json.loads(d))
        pred_num_2+=len(pred_data_2[-1]['spo_list'])
pred_num_2
# Out:
# 16081

# %%
def cross_contain(a,b):
    if a.find(b)!=-1 or b.find(a)!=-1:
        return True
    return False
for idx in range(len(pred_data_1)):
    for spo in pred_data_2[idx]['spo_list']:
        flag=True
        for temp in pred_data_1[idx]['spo_list']:
            if temp['subject']==spo['subject'] and temp['predicate']==spo['predicate']  and cross_contain(temp['object']['@value'],spo['object']['@value'])\
               and temp['object']['@value']!=spo['object']['@value'] and len(spo['object']['@value'])<4:
                flag=False
                print("1:",temp)
                print("2:",spo)
                print("="*10)
#         if flag:
#             pred_data_1[idx]['spo_list'].append(spo)
# Out:
# 1: {'object': {'@value': '何逊'}, 'subject': '车中见新林分别甚盛', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '车中见新林分别甚盛', 'object': {'@value': '梁何逊'}}
# ==========
# 1: {'object': {'@value': '唐纳德·特朗普'}, 'subject': '伊万卡·特朗普', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '伊万卡·特朗普', 'object': {'@value': '特朗普'}}
# ==========
# 1: {'object': {'@value': '庆嘉帝龙非离'}, 'subject': '龙无垢', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '龙无垢', 'object': {'@value': '庆嘉帝'}}
# ==========
# 1: {'object': {'@value': '庆嘉帝龙非离'}, 'subject': '龙无垢', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '龙无垢', 'object': {'@value': '龙非离'}}
# ==========
# 1: {'object': {'@value': '北魏孝文帝元宏'}, 'subject': '元恂', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '元恂', 'object': {'@value': '元宏'}}
# ==========
# 1: {'object': {'@value': '昂旺文章'}, 'subject': '唱给雪域的情歌', 'object_type': {'@value': '人物'}, 'predicate': '作词', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '作词', 'subject': '唱给雪域的情歌', 'object': {'@value': '昂旺'}}
# ==========
# 1: {'object': {'@value': '成都高新区金融城'}, 'subject': '成都君海投资咨询有限公司', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject_type': '企业'}
# 2: {'subject_type': '企业', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject': '成都君海投资咨询有限公司', 'object': {'@value': '成都'}}
# ==========
# 1: {'object': {'@value': '东汉末年'}, 'subject': '孙策', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '孙策', 'object': {'@value': '东汉'}}
# ==========
# 1: {'object': {'@value': '梅蒂选'}, 'subject': '梭罗河畔', 'object_type': {'@value': '人物'}, 'predicate': '作曲', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '作曲', 'subject': '梭罗河畔', 'object': {'@value': '梅蒂'}}
# ==========
# 1: {'object': {'@value': '楼钥'}, 'subject': '攻愧集', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '攻愧集', 'object': {'@value': '宋楼钥'}}
# ==========
# 1: {'object': {'@value': '刘侗 于奕正'}, 'subject': '帝京景物略', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '帝京景物略', 'object': {'@value': '刘侗'}}
# ==========
# 1: {'object': {'@value': '马 凌九九'}, 'subject': '流离', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '流离', 'object': {'@value': '凌九九'}}
# ==========
# 1: {'object': {'@value': '中华人民共和国'}, 'subject': '黄勇', 'object_type': {'@value': '国家'}, 'predicate': '国籍', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '国家'}, 'predicate': '国籍', 'subject': '黄勇', 'object': {'@value': '中华'}}
# ==========
# 1: {'object': {'@value': '李咸用'}, 'subject': '同友生春夜闻雨', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '同友生春夜闻雨', 'object': {'@value': '李咸'}}
# ==========
# 1: {'object': {'@value': '战国时期'}, 'subject': '苏秦', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '苏秦', 'object': {'@value': '战国'}}
# ==========
# 1: {'object': {'@value': '战国时期'}, 'subject': '苏代', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '苏代', 'object': {'@value': '战国'}}
# ==========
# 1: {'object': {'@value': '唐高祖李渊'}, 'subject': '真定公主', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '真定公主', 'object': {'@value': '李渊'}}
# ==========
# 1: {'object': {'@value': '安徽广德经济开发区'}, 'subject': '安徽鑫盛汽车制造有限公司', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject_type': '企业'}
# 2: {'subject_type': '企业', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject': '安徽鑫盛汽车制造有限公司', 'object': {'@value': '安徽'}}
# ==========
# 1: {'object': {'@value': '北齐神武皇帝高欢'}, 'subject': '娄昭君', 'object_type': {'@value': '人物'}, 'predicate': '丈夫', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '丈夫', 'subject': '娄昭君', 'object': {'@value': '高欢'}}
# ==========
# 1: {'object': {'@value': '王筠'}, 'subject': '昭明太子哀册文', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '昭明太子哀册文', 'object': {'@value': '梁王筠'}}
# ==========
# 1: {'object': {'@value': '明中'}, 'subject': '李用敬', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '李用敬', 'object': {'@value': '明中期'}}
# ==========
# 1: {'object': {'@value': '9万余人'}, 'subject': '樟木乡', 'object_type': {'@value': 'Number'}, 'predicate': '人口数量', 'subject_type': '行政区'}
# 2: {'subject_type': '行政区', 'object_type': {'@value': 'Number'}, 'predicate': '人口数量', 'subject': '樟木乡', 'object': {'@value': '9万'}}
# ==========
# 1: {'object': {'@value': '伍乐城 rnls'}, 'subject': '多谢失恋', 'object_type': {'@value': '人物'}, 'predicate': '作曲', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '作曲', 'subject': '多谢失恋', 'object': {'@value': '伍乐城'}}
# ==========
# 1: {'object': {'@value': '掘金队'}, 'subject': '丹佛掘金队', 'object_type': {'@value': 'Text'}, 'predicate': '简称', 'subject_type': '机构'}
# 2: {'subject_type': '机构', 'object_type': {'@value': 'Text'}, 'predicate': '简称', 'subject': '丹佛掘金队', 'object': {'@value': '掘金'}}
# ==========
# 1: {'object': {'@value': '江西省南昌市'}, 'subject': '南昌欧菲光科技有限公司', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject_type': '企业'}
# 2: {'subject_type': '企业', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject': '南昌欧菲光科技有限公司', 'object': {'@value': '南昌市'}}
# ==========
# 1: {'object': {'@value': '北京市'}, 'subject': '三里屯', 'object_type': {'@value': '城市'}, 'predicate': '所在城市', 'subject_type': '景点'}
# 2: {'subject_type': '景点', 'object_type': {'@value': '城市'}, 'predicate': '所在城市', 'subject': '三里屯', 'object': {'@value': '北京'}}
# ==========
# 1: {'object': {'@value': '金子与志一'}, 'subject': '人间失格', 'object_type': {'@value': '人物'}, 'predicate': '导演', 'subject_type': '影视作品'}
# 2: {'subject_type': '影视作品', 'object_type': {'@value': '人物'}, 'predicate': '导演', 'subject': '人间失格', 'object': {'@value': '金子'}}
# ==========
# 1: {'object': {'@value': '北京市'}, 'subject': '密云水库', 'object_type': {'@value': '城市'}, 'predicate': '所在城市', 'subject_type': '景点'}
# 2: {'subject_type': '景点', 'object_type': {'@value': '城市'}, 'predicate': '所在城市', 'subject': '密云水库', 'object': {'@value': '北京'}}
# ==========
# 1: {'object': {'@value': '县域医共体'}, 'subject': '县域医疗服务共同体', 'object_type': {'@value': 'Text'}, 'predicate': '简称', 'subject_type': '机构'}
# 2: {'subject_type': '机构', 'object_type': {'@value': 'Text'}, 'predicate': '简称', 'subject': '县域医疗服务共同体', 'object': {'@value': '医共体'}}
# ==========
# 1: {'object': {'@value': '彭辛纳'}, 'subject': '彭湃', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '彭湃', 'object': {'@value': '彭辛'}}
# ==========
# 1: {'object': {'@value': '春秋时代'}, 'subject': '季文子', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '季文子', 'object': {'@value': '春秋'}}
# ==========
# 1: {'object': {'@value': '安旭'}, 'subject': '但愿少爱你一点', 'object_type': {'@value': '人物'}, 'predicate': '歌手', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '歌手', 'subject': '但愿少爱你一点', 'object': {'@value': '安旭叶'}}
# ==========
# 1: {'object': {'@value': '婷婷'}, 'subject': '婷仔', 'object_type': {'@value': '人物'}, 'predicate': '母亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '母亲', 'subject': '婷仔', 'object': {'@value': '“婷婷'}}
# ==========
# 1: {'object': {'@value': '意大利马拉内罗'}, 'subject': '法拉利', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject_type': '企业'}
# 2: {'subject_type': '企业', 'object_type': {'@value': '地点'}, 'predicate': '总部地点', 'subject': '法拉利', 'object': {'@value': '意大利'}}
# ==========
# 1: {'object': {'@value': '网络红人冷兮儿'}, 'subject': '御灵传说之救世主', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '御灵传说之救世主', 'object': {'@value': '冷兮儿'}}
# ==========
# 1: {'object': {'@value': '萧萧 大理石'}, 'subject': '公主的魔法项链', 'object_type': {'@value': '人物'}, 'predicate': '作词', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '作词', 'subject': '公主的魔法项链', 'object': {'@value': '萧萧'}}
# ==========
# 1: {'object': {'@value': '邪神洛基'}, 'subject': '耶梦加得', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '耶梦加得', 'object': {'@value': '洛基'}}
# ==========
# 1: {'object': {'@value': '邪神洛基'}, 'subject': '海拉', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '海拉', 'object': {'@value': '洛基'}}
# ==========
# 1: {'object': {'@value': '孟山人'}, 'subject': '孟浩然', 'object_type': {'@value': 'Text'}, 'predicate': '号', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '号', 'subject': '孟浩然', 'object': {'@value': '孟山'}}
# ==========
# 1: {'object': {'@value': '明仁宗朱高炽'}, 'subject': '嘉兴公主', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '嘉兴公主', 'object': {'@value': '明仁宗'}}
# ==========
# 1: {'object': {'@value': '明仁宗朱高炽'}, 'subject': '嘉兴公主', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '嘉兴公主', 'object': {'@value': '朱高炽'}}
# ==========
# 1: {'object': {'@value': '冯骥才'}, 'subject': '高女人和她的矮丈夫', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '高女人和她的矮丈夫', 'object': {'@value': '冯骥'}}
# ==========
# 1: {'object': {'@value': '夏敢若何'}, 'subject': '爱吃爱喝爱生活', 'object_type': {'@value': '人物'}, 'predicate': '作词', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '作词', 'subject': '爱吃爱喝爱生活', 'object': {'@value': '夏敢若'}}
# ==========
# 1: {'object': {'@value': '中华人民共和国'}, 'subject': '刘禹', 'object_type': {'@value': '国家'}, 'predicate': '国籍', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '国家'}, 'predicate': '国籍', 'subject': '刘禹', 'object': {'@value': '中华'}}
# ==========
# 1: {'object': {'@value': '派克\\帕克'}, 'subject': '派克汉尼汾', 'object_type': {'@value': 'Text'}, 'predicate': '简称', 'subject_type': '机构'}
# 2: {'subject_type': '机构', 'object_type': {'@value': 'Text'}, 'predicate': '简称', 'subject': '派克汉尼汾', 'object': {'@value': '派克'}}
# ==========
# 1: {'object': {'@value': '杨端和'}, 'subject': '语言研究应用SPSS软件实例大全', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '语言研究应用SPSS软件实例大全', 'object': {'@value': '杨端'}}
# ==========
# 1: {'object': {'@value': '春秋时期'}, 'subject': '豫让', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '豫让', 'object': {'@value': '春秋'}}
# ==========
# 1: {'object': {'@value': '春秋时期'}, 'subject': '伍子胥', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '伍子胥', 'object': {'@value': '春秋'}}
# ==========
# 1: {'object': {'@value': '潘行紫旻'}, 'subject': '今生永相伴', 'object_type': {'@value': '人物'}, 'predicate': '作曲', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '人物'}, 'predicate': '作曲', 'subject': '今生永相伴', 'object': {'@value': '潘行'}}
# ==========
# 1: {'object': {'@value': '明代'}, 'subject': '虞程', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject_type': '历史人物'}
# 2: {'subject_type': '历史人物', 'object_type': {'@value': 'Text'}, 'predicate': '朝代', 'subject': '虞程', 'object': {'@value': '明'}}
# ==========
# 1: {'object': {'@value': '”金唱片”', 'inWork': '流连', 'onDate': '1982年'}, 'subject': '费翔', 'object_type': {'@value': '奖项', 'inWork': '作品', 'onDate': 'Date'}, 'predicate': '获奖', 'subject_type': '娱乐人物'}
# 2: {'subject_type': '娱乐人物', 'object_type': {'@value': '奖项'}, 'predicate': '获奖', 'subject': '费翔', 'object': {'@value': '金唱片'}}
# ==========
# 1: {'object': {'@value': '纯色角5'}, 'subject': '热浪', 'object_type': {'@value': '音乐专辑'}, 'predicate': '所属专辑', 'subject_type': '歌曲'}
# 2: {'subject_type': '歌曲', 'object_type': {'@value': '音乐专辑'}, 'predicate': '所属专辑', 'subject': '热浪', 'object': {'@value': '纯色角'}}
# ==========
# 1: {'object': {'@value': '辽景宗耶律贤'}, 'subject': '萧绰', 'object_type': {'@value': '人物'}, 'predicate': '丈夫', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '丈夫', 'subject': '萧绰', 'object': {'@value': '耶律贤'}}
# ==========
# 1: {'object': {'@value': '刘烨'}, 'subject': '老男孩', 'object_type': {'@value': '人物'}, 'predicate': '主演', 'subject_type': '影视作品'}
# 2: {'subject_type': '影视作品', 'object_type': {'@value': '人物'}, 'predicate': '主演', 'subject': '老男孩', 'object': {'@value': '搜刘烨'}}
# ==========
# 1: {'object': {'@value': '唐太宗李世民'}, 'subject': '晋阳公主', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '晋阳公主', 'object': {'@value': '李世民'}}
# ==========
# 1: {'object': {'@value': '著名作曲家丁丕业'}, 'subject': '丁铃', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '丁铃', 'object': {'@value': '丁丕业'}}
# ==========
# 1: {'object': {'@value': '郭初永真'}, 'subject': '郭台铭', 'object_type': {'@value': '人物'}, 'predicate': '母亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '母亲', 'subject': '郭台铭', 'object': {'@value': '郭初永'}}
# ==========
# 1: {'object': {'@value': '陆定原'}, 'subject': '陆小曼', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject_type': '人物'}
# 2: {'subject_type': '人物', 'object_type': {'@value': '人物'}, 'predicate': '父亲', 'subject': '陆小曼', 'object': {'@value': '陆定'}}
# ==========
# 1: {'object': {'@value': '于程雷'}, 'subject': '中国梦之声', 'object_type': {'@value': '人物'}, 'predicate': '主持人', 'subject_type': '电视综艺'}
# 2: {'subject_type': '电视综艺', 'object_type': {'@value': '人物'}, 'predicate': '主持人', 'subject': '中国梦之声', 'object': {'@value': '程雷'}}
# ==========
# 1: {'object': {'@value': '从维熙'}, 'subject': '走向混沌·混沌之初到第十三名', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '走向混沌·混沌之初到第十三名', 'object': {'@value': '维熙'}}
# ==========
# 1: {'object': {'@value': '季恒恒点校'}, 'subject': '钦定廓尔喀纪略', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject_type': '图书作品'}
# 2: {'subject_type': '图书作品', 'object_type': {'@value': '人物'}, 'predicate': '作者', 'subject': '钦定廓尔喀纪略', 'object': {'@value': '季恒恒'}}
# ==========
